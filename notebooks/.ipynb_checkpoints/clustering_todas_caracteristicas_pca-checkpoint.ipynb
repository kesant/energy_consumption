# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import davies_bouldin_score
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import fcluster
from scipy.cluster.hierarchy import linkage, dendrogram
from kneebow.rotor import Rotor
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
import seaborn as sns
import numpy as np
import os
import re

# %% [markdown]
# ## Funciones auxiliares

# %%
#We calculate or k-distance for determinate our eps value.
def calculate_kn_distance(X, neigh=2):
    neigh = NearestNeighbors(n_neighbors=neigh)
    nbrs = neigh.fit(X)
    distances, indices = nbrs.kneighbors(X)
    return distances[:,1:].reshape(-1)

#We get the eps exact value using kneebow, this function allows
#us to find the elbow of a curve by rotating the curve and taking
#the minimum value.
def get_eps(X, neigh=2):
    eps_dist = np.sort(calculate_kn_distance(X, neigh=neigh))
    rotor = Rotor()
    curve_xy = np.concatenate([np.arange(eps_dist.shape[0]).reshape(-1, 1), eps_dist.reshape(-1, 1)],1)
    rotor.fit_rotate(curve_xy)
    rotor.plot_elbow()
    e_idx = rotor.get_elbow_index()
    return curve_xy[e_idx]

# %% [markdown]
# ## carga de datos

# %%
file_path="../data/interim/estadisticas_edificios.csv"

# %%
data = pd.read_csv(file_path)
data.head()
# Out:
#                          type_building  \
# 0  RefBldgFullServiceRestaurantNew2004
# 1  RefBldgFullServiceRestaurantNew2004
# 2  RefBldgFullServiceRestaurantNew2004
# 3  RefBldgFullServiceRestaurantNew2004
# 4  RefBldgFullServiceRestaurantNew2004
#
#    Electricity:Facility [kW](Hourly)_mean  \
# 0                               36.968830
# 1                               37.357872
# 2                               37.896555
# 3                               35.892184
# 4                               35.976038
#
#    Electricity:Facility [kW](Hourly)_std_dev  \
# 0                                  13.139998
# 1                                  13.459672
# 2                                  13.945362
# 3                                  12.083141
# 4                                  12.127984
#
#    Electricity:Facility [kW](Hourly)_max_value  \
# 0                                    71.651343
# 1                                    73.124359
# 2                                    72.745300
# 3                                    71.557828
# 4                                    70.203381
#
#    Electricity:Facility [kW](Hourly)_min_value  \
# 0                                    14.590618
# 1                                    14.610946
# 2                                    14.594486
# 3                                    14.600000
# 4                                    14.593106
#
#    Electricity:Facility [kW](Hourly)_25_percentile  \
# 0                                        33.836563
# 1                                        34.289907
# 2                                        34.285619
# 3                                        33.768150
# 4                                        33.934022
#
#    Electricity:Facility [kW](Hourly)_50_percentile  \
# 0                                        38.877634
# 1                                        39.231781
# 2                                        39.321435
# 3                                        38.689354
# 4                                        38.713755
#
#    Electricity:Facility [kW](Hourly)_75_percentile  \
# 0                                        43.668457
# 1                                        44.710691
# 2                                        45.983973
# 3                                        42.586655
# 4                                        42.615663
#
#    Fans:Electricity [kW](Hourly)_mean  Fans:Electricity [kW](Hourly)_std_dev  \
# 0                            3.331869                               1.490142
# 1                            3.327967                               1.488397
# 2                            3.327124                               1.488020
# 3                            3.303988                               1.477673
# 4                            3.323298                               1.486309
#
#    ...  InteriorLights:Electricity [kW](Hourly)_25_percentile  \
# 0  ...                                           8.032369
# 1  ...                                           8.032369
# 2  ...                                           8.032369
# 3  ...                                           8.032369
# 4  ...                                           8.032369
#
#    InteriorLights:Electricity [kW](Hourly)_50_percentile  \
# 0                                           9.179851
# 1                                           9.179851
# 2                                           9.179851
# 3                                           9.179851
# 4                                           9.179851
#
#    InteriorLights:Electricity [kW](Hourly)_75_percentile  \
# 0                                           9.179851
# 1                                           9.179851
# 2                                           9.179851
# 3                                           9.179851
# 4                                           9.179851
#
#    InteriorEquipment:Electricity [kW](Hourly)_mean  \
# 0                                        18.995908
# 1                                        18.995908
# 2                                        18.995908
# 3                                        18.995908
# 4                                        18.995908
#
#    InteriorEquipment:Electricity [kW](Hourly)_std_dev  \
# 0                                           7.265027
# 1                                           7.265027
# 2                                           7.265027
# 3                                           7.265027
# 4                                           7.265027
#
#    InteriorEquipment:Electricity [kW](Hourly)_max_value  \
# 0                                            26.9147
# 1                                            26.9147
# 2                                            26.9147
# 3                                            26.9147
# 4                                            26.9147
#
#    InteriorEquipment:Electricity [kW](Hourly)_min_value  \
# 0                                             7.4902
# 1                                             7.4902
# 2                                             7.4902
# 3                                             7.4902
# 4                                             7.4902
#
#    InteriorEquipment:Electricity [kW](Hourly)_25_percentile  \
# 0                                          16.615675
# 1                                          16.615675
# 2                                          16.615675
# 3                                          16.615675
# 4                                          16.615675
#
#    InteriorEquipment:Electricity [kW](Hourly)_50_percentile  \
# 0                                            19.4245
# 1                                            19.4245
# 2                                            19.4245
# 3                                            19.4245
# 4                                            19.4245
#
#    InteriorEquipment:Electricity [kW](Hourly)_75_percentile
# 0                                            26.9147
# 1                                            26.9147
# 2                                            26.9147
# 3                                            26.9147
# 4                                            26.9147
#
# [5 rows x 43 columns]

# %%
data.columns
# Out:
# Index(['type_building', 'Electricity:Facility [kW](Hourly)_mean',
#        'Electricity:Facility [kW](Hourly)_std_dev',
#        'Electricity:Facility [kW](Hourly)_max_value',
#        'Electricity:Facility [kW](Hourly)_min_value',
#        'Electricity:Facility [kW](Hourly)_25_percentile',
#        'Electricity:Facility [kW](Hourly)_50_percentile',
#        'Electricity:Facility [kW](Hourly)_75_percentile',
#        'Fans:Electricity [kW](Hourly)_mean',
#        'Fans:Electricity [kW](Hourly)_std_dev',
#        'Fans:Electricity [kW](Hourly)_max_value',
#        'Fans:Electricity [kW](Hourly)_min_value',
#        'Fans:Electricity [kW](Hourly)_25_percentile',
#        'Fans:Electricity [kW](Hourly)_50_percentile',
#        'Fans:Electricity [kW](Hourly)_75_percentile',
#        'Cooling:Electricity [kW](Hourly)_mean',
#        'Cooling:Electricity [kW](Hourly)_std_dev',
#        'Cooling:Electricity [kW](Hourly)_max_value',
#        'Cooling:Electricity [kW](Hourly)_min_value',
#        'Cooling:Electricity [kW](Hourly)_25_percentile',
#        'Cooling:Electricity [kW](Hourly)_50_percentile',
#        'Cooling:Electricity [kW](Hourly)_75_percentile',
#        'Heating:Electricity [kW](Hourly)_mean',
#        'Heating:Electricity [kW](Hourly)_std_dev',
#        'Heating:Electricity [kW](Hourly)_max_value',
#        'Heating:Electricity [kW](Hourly)_min_value',
#        'Heating:Electricity [kW](Hourly)_25_percentile',
#        'Heating:Electricity [kW](Hourly)_50_percentile',
#        'Heating:Electricity [kW](Hourly)_75_percentile',
#        'InteriorLights:Electricity [kW](Hourly)_mean',
#        'InteriorLights:Electricity [kW](Hourly)_std_dev',
#        'InteriorLights:Electricity [kW](Hourly)_max_value',
#        'InteriorLights:Electricity [kW](Hourly)_min_value',
#        'InteriorLights:Electricity [kW](Hourly)_25_percentile',
#        'InteriorLights:Electricity [kW](Hourly)_50_percentile',
#        'InteriorLights:Electricity [kW](Hourly)_75_percentile',
#        'InteriorEquipment:Electricity [kW](Hourly)_mean',
#        'InteriorEquipment:Electricity [kW](Hourly)_std_dev',
#        'InteriorEquipment:Electricity [kW](Hourly)_max_value',
#        'InteriorEquipment:Electricity [kW](Hourly)_min_value',
#        'InteriorEquipment:Electricity [kW](Hourly)_25_percentile',
#        'InteriorEquipment:Electricity [kW](Hourly)_50_percentile',
#        'InteriorEquipment:Electricity [kW](Hourly)_75_percentile'],
#       dtype='object')

# %%
# Obtener un resumen estadístico y mostrar la información general del conjunto de datos
summary = data.describe()
summary
# Out:
#        Electricity:Facility [kW](Hourly)_mean  \
# count                               80.000000
# mean                               205.896959
# std                                294.490158
# min                                  7.474270
# 25%                                 32.447086
# 50%                                 78.139872
# 75%                                218.748632
# max                               1120.479725
#
#        Electricity:Facility [kW](Hourly)_std_dev  \
# count                                  80.000000
# mean                                   94.554094
# std                                   128.967601
# min                                     4.002892
# 25%                                    17.795171
# 50%                                    40.073529
# 75%                                    81.871898
# max                                   478.877942
#
#        Electricity:Facility [kW](Hourly)_max_value  \
# count                                    80.000000
# mean                                    443.477615
# std                                     549.446174
# min                                      19.802128
# 25%                                      89.810725
# 50%                                     224.347158
# 75%                                     416.974453
# max                                    1886.608295
#
#        Electricity:Facility [kW](Hourly)_min_value  \
# count                                    80.000000
# mean                                     70.457995
# std                                     114.916877
# min                                       1.925019
# 25%                                       8.699267
# 50%                                      25.164031
# 75%                                      78.435727
# max                                     508.413289
#
#        Electricity:Facility [kW](Hourly)_25_percentile  \
# count                                        80.000000
# mean                                        127.069353
# std                                         220.106359
# min                                           4.778024
# 25%                                          17.785496
# 50%                                          44.778556
# 75%                                         118.747199
# max                                         952.791133
#
#        Electricity:Facility [kW](Hourly)_50_percentile  \
# count                                        80.000000
# mean                                        180.856123
# std                                         274.716614
# min                                           6.033994
# 25%                                          27.533792
# 50%                                          62.731332
# 75%                                         197.050593
# max                                        1066.621718
#
#        Electricity:Facility [kW](Hourly)_75_percentile  \
# count                                        80.000000
# mean                                        277.715774
# std                                         385.373052
# min                                          11.556660
# 25%                                          48.293093
# 50%                                         110.190792
# 75%                                         283.287781
# max                                        1383.350524
#
#        Fans:Electricity [kW](Hourly)_mean  \
# count                           80.000000
# mean                            17.075134
# std                             24.649374
# min                              1.217192
# 25%                              3.041448
# 50%                              5.733951
# 75%                             21.543638
# max                            102.154344
#
#        Fans:Electricity [kW](Hourly)_std_dev  \
# count                              80.000000
# mean                                7.016523
# std                                 9.107792
# min                                 0.711591
# 25%                                 1.416750
# 50%                                 4.100985
# 75%                                 6.633711
# max                                37.823520
#
#        Fans:Electricity [kW](Hourly)_max_value  ...  \
# count                                80.000000  ...
# mean                                 45.769114  ...
# std                                  69.280486  ...
# min                                   2.184205  ...
# 25%                                   7.472911  ...
# 50%                                  11.780199  ...
# 75%                                  37.988283  ...
# max                                 304.000110  ...
#
#        InteriorLights:Electricity [kW](Hourly)_25_percentile  \
# count                                          80.000000
# mean                                           13.192541
# std                                            14.829699
# min                                             0.275003
# 25%                                             3.105893
# 50%                                             4.801828
# 75%                                            18.128048
# max                                            46.093034
#
#        InteriorLights:Electricity [kW](Hourly)_50_percentile  \
# count                                          80.000000
# mean                                           21.508703
# std                                            24.725756
# min                                             0.550005
# 25%                                             5.451126
# 50%                                            11.914006
# 75%                                            23.766720
# max                                           100.150657
#
#        InteriorLights:Electricity [kW](Hourly)_75_percentile  \
# count                                          80.000000
# mean                                           84.586268
# std                                           117.099512
# min                                             3.711679
# 25%                                            20.528760
# 50%                                            37.735226
# 75%                                            67.296722
# max                                           448.566544
#
#        InteriorEquipment:Electricity [kW](Hourly)_mean  \
# count                                        80.000000
# mean                                         53.206147
# std                                          73.554009
# min                                           2.781765
# 25%                                          11.311712
# 50%                                          25.334649
# 75%                                          58.264945
# max                                         265.854193
#
#        InteriorEquipment:Electricity [kW](Hourly)_std_dev  \
# count                                          80.000000
# mean                                           24.728418
# std                                            31.327799
# min                                             1.278151
# 25%                                             4.654335
# 50%                                            13.133033
# 75%                                            27.107491
# max                                           116.539481
#
#        InteriorEquipment:Electricity [kW](Hourly)_max_value  \
# count                                          80.000000
# mean                                           93.059567
# std                                           119.627218
# min                                             4.950048
# 25%                                            16.250509
# 50%                                            49.700376
# 75%                                           113.141618
# max                                           448.566544
#
#        InteriorEquipment:Electricity [kW](Hourly)_min_value  \
# count                                          80.000000
# mean                                           26.638005
# std                                            41.686298
# min                                             1.011600
# 25%                                             4.198793
# 50%                                             8.760066
# 75%                                            23.552351
# max                                           149.522181
#
#        InteriorEquipment:Electricity [kW](Hourly)_25_percentile  \
# count                                          80.000000
# mean                                           33.139539
# std                                            47.366172
# min                                             1.011600
# 25%                                             7.411378
# 50%                                            15.207416
# 75%                                            33.079399
# max                                           174.442545
#
#        InteriorEquipment:Electricity [kW](Hourly)_50_percentile  \
# count                                          80.000000
# mean                                           44.721192
# std                                            61.317985
# min                                             1.011600
# 25%                                            11.303727
# 50%                                            22.338642
# 75%                                            44.437106
# max                                           199.362908
#
#        InteriorEquipment:Electricity [kW](Hourly)_75_percentile
# count                                          80.000000
# mean                                           77.250456
# std                                           109.151424
# min                                             4.400043
# 25%                                            16.250509
# 50%                                            38.770934
# 75%                                            78.163553
# max                                           398.725817
#
# [8 rows x 42 columns]

# %%
info = data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 43 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   type_building                                             80 non-null     object
#  1   Electricity:Facility [kW](Hourly)_mean                    80 non-null     float64
#  2   Electricity:Facility [kW](Hourly)_std_dev                 80 non-null     float64
#  3   Electricity:Facility [kW](Hourly)_max_value               80 non-null     float64
#  4   Electricity:Facility [kW](Hourly)_min_value               80 non-null     float64
#  5   Electricity:Facility [kW](Hourly)_25_percentile           80 non-null     float64
#  6   Electricity:Facility [kW](Hourly)_50_percentile           80 non-null     float64
#  7   Electricity:Facility [kW](Hourly)_75_percentile           80 non-null     float64
#  8   Fans:Electricity [kW](Hourly)_mean                        80 non-null     float64
#  9   Fans:Electricity [kW](Hourly)_std_dev                     80 non-null     float64
#  10  Fans:Electricity [kW](Hourly)_max_value                   80 non-null     float64
#  11  Fans:Electricity [kW](Hourly)_min_value                   80 non-null     float64
#  12  Fans:Electricity [kW](Hourly)_25_percentile               80 non-null     float64
#  13  Fans:Electricity [kW](Hourly)_50_percentile               80 non-null     float64
#  14  Fans:Electricity [kW](Hourly)_75_percentile               80 non-null     float64
#  15  Cooling:Electricity [kW](Hourly)_mean                     80 non-null     float64
#  16  Cooling:Electricity [kW](Hourly)_std_dev                  80 non-null     float64
#  17  Cooling:Electricity [kW](Hourly)_max_value                80 non-null     float64
#  18  Cooling:Electricity [kW](Hourly)_min_value                80 non-null     float64
#  19  Cooling:Electricity [kW](Hourly)_25_percentile            80 non-null     float64
#  20  Cooling:Electricity [kW](Hourly)_50_percentile            80 non-null     float64
#  21  Cooling:Electricity [kW](Hourly)_75_percentile            80 non-null     float64
#  22  Heating:Electricity [kW](Hourly)_mean                     80 non-null     float64
#  23  Heating:Electricity [kW](Hourly)_std_dev                  80 non-null     float64
#  24  Heating:Electricity [kW](Hourly)_max_value                80 non-null     float64
#  25  Heating:Electricity [kW](Hourly)_min_value                80 non-null     float64
#  26  Heating:Electricity [kW](Hourly)_25_percentile            80 non-null     float64
#  27  Heating:Electricity [kW](Hourly)_50_percentile            80 non-null     float64
#  28  Heating:Electricity [kW](Hourly)_75_percentile            80 non-null     float64
#  29  InteriorLights:Electricity [kW](Hourly)_mean              80 non-null     float64
#  30  InteriorLights:Electricity [kW](Hourly)_std_dev           80 non-null     float64
#  31  InteriorLights:Electricity [kW](Hourly)_max_value         80 non-null     float64
#  32  InteriorLights:Electricity [kW](Hourly)_min_value         80 non-null     float64
#  33  InteriorLights:Electricity [kW](Hourly)_25_percentile     80 non-null     float64
#  34  InteriorLights:Electricity [kW](Hourly)_50_percentile     80 non-null     float64
#  35  InteriorLights:Electricity [kW](Hourly)_75_percentile     80 non-null     float64
#  36  InteriorEquipment:Electricity [kW](Hourly)_mean           80 non-null     float64
#  37  InteriorEquipment:Electricity [kW](Hourly)_std_dev        80 non-null     float64
#  38  InteriorEquipment:Electricity [kW](Hourly)_max_value      80 non-null     float64
#  39  InteriorEquipment:Electricity [kW](Hourly)_min_value      80 non-null     float64
#  40  InteriorEquipment:Electricity [kW](Hourly)_25_percentile  80 non-null     float64
#  41  InteriorEquipment:Electricity [kW](Hourly)_50_percentile  80 non-null     float64
#  42  InteriorEquipment:Electricity [kW](Hourly)_75_percentile  80 non-null     float64
# dtypes: float64(42), object(1)
# memory usage: 27.0+ KB

# %%
# Identificar valores faltantes
missing_values = data.isnull().sum()
missing_values
# Out:
# type_building                                               0
# Electricity:Facility [kW](Hourly)_mean                      0
# Electricity:Facility [kW](Hourly)_std_dev                   0
# Electricity:Facility [kW](Hourly)_max_value                 0
# Electricity:Facility [kW](Hourly)_min_value                 0
# Electricity:Facility [kW](Hourly)_25_percentile             0
# Electricity:Facility [kW](Hourly)_50_percentile             0
# Electricity:Facility [kW](Hourly)_75_percentile             0
# Fans:Electricity [kW](Hourly)_mean                          0
# Fans:Electricity [kW](Hourly)_std_dev                       0
# Fans:Electricity [kW](Hourly)_max_value                     0
# Fans:Electricity [kW](Hourly)_min_value                     0
# Fans:Electricity [kW](Hourly)_25_percentile                 0
# Fans:Electricity [kW](Hourly)_50_percentile                 0
# Fans:Electricity [kW](Hourly)_75_percentile                 0
# Cooling:Electricity [kW](Hourly)_mean                       0
# Cooling:Electricity [kW](Hourly)_std_dev                    0
# Cooling:Electricity [kW](Hourly)_max_value                  0
# Cooling:Electricity [kW](Hourly)_min_value                  0
# Cooling:Electricity [kW](Hourly)_25_percentile              0
# Cooling:Electricity [kW](Hourly)_50_percentile              0
# Cooling:Electricity [kW](Hourly)_75_percentile              0
# Heating:Electricity [kW](Hourly)_mean                       0
# Heating:Electricity [kW](Hourly)_std_dev                    0
# Heating:Electricity [kW](Hourly)_max_value                  0
# Heating:Electricity [kW](Hourly)_min_value                  0
# Heating:Electricity [kW](Hourly)_25_percentile              0
# Heating:Electricity [kW](Hourly)_50_percentile              0
# Heating:Electricity [kW](Hourly)_75_percentile              0
# InteriorLights:Electricity [kW](Hourly)_mean                0
# InteriorLights:Electricity [kW](Hourly)_std_dev             0
# InteriorLights:Electricity [kW](Hourly)_max_value           0
# InteriorLights:Electricity [kW](Hourly)_min_value           0
# InteriorLights:Electricity [kW](Hourly)_25_percentile       0
# InteriorLights:Electricity [kW](Hourly)_50_percentile       0
# InteriorLights:Electricity [kW](Hourly)_75_percentile       0
# InteriorEquipment:Electricity [kW](Hourly)_mean             0
# InteriorEquipment:Electricity [kW](Hourly)_std_dev          0
# InteriorEquipment:Electricity [kW](Hourly)_max_value        0
# InteriorEquipment:Electricity [kW](Hourly)_min_value        0
# InteriorEquipment:Electricity [kW](Hourly)_25_percentile    0
# InteriorEquipment:Electricity [kW](Hourly)_50_percentile    0
# InteriorEquipment:Electricity [kW](Hourly)_75_percentile    0
# dtype: int64

# %%
# Seleccionar todas las columnas numéricas para la estandarización
numeric_columns = data.select_dtypes(include=['float64']).columns

# Estandarizar los datos
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data[numeric_columns])

# Convertir de nuevo a un DataFrame para mantener la consistencia
data_scaled_df = pd.DataFrame(data_scaled, columns=numeric_columns)
# Añadir la columna 'type_building' de nuevo
data_scaled_df['type_building'] = data['type_building']

# Mostrar los primeros registros del DataFrame estandarizado
data_scaled_df.head()
# Out:
#    Electricity:Facility [kW](Hourly)_mean  \
# 0                               -0.577248
# 1                               -0.575919
# 2                               -0.574078
# 3                               -0.580927
# 4                               -0.580641
#
#    Electricity:Facility [kW](Hourly)_std_dev  \
# 0                                  -0.635258
# 1                                  -0.632764
# 2                                  -0.628974
# 3                                  -0.643505
# 4                                  -0.643155
#
#    Electricity:Facility [kW](Hourly)_max_value  \
# 0                                    -0.680999
# 1                                    -0.678301
# 2                                    -0.678995
# 3                                    -0.681170
# 4                                    -0.683651
#
#    Electricity:Facility [kW](Hourly)_min_value  \
# 0                                    -0.489222
# 1                                    -0.489044
# 2                                    -0.489188
# 3                                    -0.489140
# 4                                    -0.489200
#
#    Electricity:Facility [kW](Hourly)_25_percentile  \
# 0                                        -0.426253
# 1                                        -0.424180
# 2                                        -0.424200
# 3                                        -0.426566
# 4                                        -0.425808
#
#    Electricity:Facility [kW](Hourly)_50_percentile  \
# 0                                        -0.520079
# 1                                        -0.518781
# 2                                        -0.518453
# 3                                        -0.520768
# 4                                        -0.520679
#
#    Electricity:Facility [kW](Hourly)_75_percentile  \
# 0                                        -0.611158
# 1                                        -0.608437
# 2                                        -0.605112
# 3                                        -0.613983
# 4                                        -0.613908
#
#    Fans:Electricity [kW](Hourly)_mean  Fans:Electricity [kW](Hourly)_std_dev  \
# 0                           -0.561068                              -0.610603
# 1                           -0.561227                              -0.610796
# 2                           -0.561262                              -0.610838
# 3                           -0.562206                              -0.611981
# 4                           -0.561418                              -0.611027
#
#    Fans:Electricity [kW](Hourly)_max_value  ...  \
# 0                                -0.606728  ...
# 1                                -0.606796  ...
# 2                                -0.606811  ...
# 3                                -0.607214  ...
# 4                                -0.606877  ...
#
#    InteriorLights:Electricity [kW](Hourly)_50_percentile  \
# 0                                           -0.50177
# 1                                           -0.50177
# 2                                           -0.50177
# 3                                           -0.50177
# 4                                           -0.50177
#
#    InteriorLights:Electricity [kW](Hourly)_75_percentile  \
# 0                                          -0.648014
# 1                                          -0.648014
# 2                                          -0.648014
# 3                                          -0.648014
# 4                                          -0.648014
#
#    InteriorEquipment:Electricity [kW](Hourly)_mean  \
# 0                                        -0.468038
# 1                                        -0.468038
# 2                                        -0.468038
# 3                                        -0.468038
# 4                                        -0.468038
#
#    InteriorEquipment:Electricity [kW](Hourly)_std_dev  \
# 0                                          -0.560958
# 1                                          -0.560958
# 2                                          -0.560958
# 3                                          -0.560958
# 4                                          -0.560958
#
#    InteriorEquipment:Electricity [kW](Hourly)_max_value  \
# 0                                          -0.556413
# 1                                          -0.556413
# 2                                          -0.556413
# 3                                          -0.556413
# 4                                          -0.556413
#
#    InteriorEquipment:Electricity [kW](Hourly)_min_value  \
# 0                                          -0.462229
# 1                                          -0.462229
# 2                                          -0.462229
# 3                                          -0.462229
# 4                                          -0.462229
#
#    InteriorEquipment:Electricity [kW](Hourly)_25_percentile  \
# 0                                          -0.351055
# 1                                          -0.351055
# 2                                          -0.351055
# 3                                          -0.351055
# 4                                          -0.351055
#
#    InteriorEquipment:Electricity [kW](Hourly)_50_percentile  \
# 0                                          -0.415152
# 1                                          -0.415152
# 2                                          -0.415152
# 3                                          -0.415152
# 4                                          -0.415152
#
#    InteriorEquipment:Electricity [kW](Hourly)_75_percentile  \
# 0                                          -0.464065
# 1                                          -0.464065
# 2                                          -0.464065
# 3                                          -0.464065
# 4                                          -0.464065
#
#                          type_building
# 0  RefBldgFullServiceRestaurantNew2004
# 1  RefBldgFullServiceRestaurantNew2004
# 2  RefBldgFullServiceRestaurantNew2004
# 3  RefBldgFullServiceRestaurantNew2004
# 4  RefBldgFullServiceRestaurantNew2004
#
# [5 rows x 43 columns]

# %%
# Calcular la matriz de correlación
correlation_matrix = data_scaled_df.iloc[:,:-1].corr()

# Mostrar la matriz de correlación utilizando un mapa de calor
plt.figure(figsize=(20, 15))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlación')
plt.show()

# %%
# Separar las características numéricas
features = data_scaled_df.drop(columns=['type_building'])

# %%
features.head()
# Out:
#    Electricity:Facility [kW](Hourly)_mean  \
# 0                               -0.577248
# 1                               -0.575919
# 2                               -0.574078
# 3                               -0.580927
# 4                               -0.580641
#
#    Electricity:Facility [kW](Hourly)_std_dev  \
# 0                                  -0.635258
# 1                                  -0.632764
# 2                                  -0.628974
# 3                                  -0.643505
# 4                                  -0.643155
#
#    Electricity:Facility [kW](Hourly)_max_value  \
# 0                                    -0.680999
# 1                                    -0.678301
# 2                                    -0.678995
# 3                                    -0.681170
# 4                                    -0.683651
#
#    Electricity:Facility [kW](Hourly)_min_value  \
# 0                                    -0.489222
# 1                                    -0.489044
# 2                                    -0.489188
# 3                                    -0.489140
# 4                                    -0.489200
#
#    Electricity:Facility [kW](Hourly)_25_percentile  \
# 0                                        -0.426253
# 1                                        -0.424180
# 2                                        -0.424200
# 3                                        -0.426566
# 4                                        -0.425808
#
#    Electricity:Facility [kW](Hourly)_50_percentile  \
# 0                                        -0.520079
# 1                                        -0.518781
# 2                                        -0.518453
# 3                                        -0.520768
# 4                                        -0.520679
#
#    Electricity:Facility [kW](Hourly)_75_percentile  \
# 0                                        -0.611158
# 1                                        -0.608437
# 2                                        -0.605112
# 3                                        -0.613983
# 4                                        -0.613908
#
#    Fans:Electricity [kW](Hourly)_mean  Fans:Electricity [kW](Hourly)_std_dev  \
# 0                           -0.561068                              -0.610603
# 1                           -0.561227                              -0.610796
# 2                           -0.561262                              -0.610838
# 3                           -0.562206                              -0.611981
# 4                           -0.561418                              -0.611027
#
#    Fans:Electricity [kW](Hourly)_max_value  ...  \
# 0                                -0.606728  ...
# 1                                -0.606796  ...
# 2                                -0.606811  ...
# 3                                -0.607214  ...
# 4                                -0.606877  ...
#
#    InteriorLights:Electricity [kW](Hourly)_25_percentile  \
# 0                                          -0.350157
# 1                                          -0.350157
# 2                                          -0.350157
# 3                                          -0.350157
# 4                                          -0.350157
#
#    InteriorLights:Electricity [kW](Hourly)_50_percentile  \
# 0                                           -0.50177
# 1                                           -0.50177
# 2                                           -0.50177
# 3                                           -0.50177
# 4                                           -0.50177
#
#    InteriorLights:Electricity [kW](Hourly)_75_percentile  \
# 0                                          -0.648014
# 1                                          -0.648014
# 2                                          -0.648014
# 3                                          -0.648014
# 4                                          -0.648014
#
#    InteriorEquipment:Electricity [kW](Hourly)_mean  \
# 0                                        -0.468038
# 1                                        -0.468038
# 2                                        -0.468038
# 3                                        -0.468038
# 4                                        -0.468038
#
#    InteriorEquipment:Electricity [kW](Hourly)_std_dev  \
# 0                                          -0.560958
# 1                                          -0.560958
# 2                                          -0.560958
# 3                                          -0.560958
# 4                                          -0.560958
#
#    InteriorEquipment:Electricity [kW](Hourly)_max_value  \
# 0                                          -0.556413
# 1                                          -0.556413
# 2                                          -0.556413
# 3                                          -0.556413
# 4                                          -0.556413
#
#    InteriorEquipment:Electricity [kW](Hourly)_min_value  \
# 0                                          -0.462229
# 1                                          -0.462229
# 2                                          -0.462229
# 3                                          -0.462229
# 4                                          -0.462229
#
#    InteriorEquipment:Electricity [kW](Hourly)_25_percentile  \
# 0                                          -0.351055
# 1                                          -0.351055
# 2                                          -0.351055
# 3                                          -0.351055
# 4                                          -0.351055
#
#    InteriorEquipment:Electricity [kW](Hourly)_50_percentile  \
# 0                                          -0.415152
# 1                                          -0.415152
# 2                                          -0.415152
# 3                                          -0.415152
# 4                                          -0.415152
#
#    InteriorEquipment:Electricity [kW](Hourly)_75_percentile
# 0                                          -0.464065
# 1                                          -0.464065
# 2                                          -0.464065
# 3                                          -0.464065
# 4                                          -0.464065
#
# [5 rows x 42 columns]

# %% [markdown]
# ## PCA

# %%
# Create a PCA instance: pca
pca = PCA()
# Fit the pipeline to 'samples'
pca.fit(features)
print(pca.explained_variance_)
# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.xticks(features)
plt.show()
# Out:
# [2.70101397e+01 4.89156137e+00 4.18109393e+00 1.88620440e+00
#  9.92233073e-01 8.01739478e-01 2.71195086e-01 1.44760859e-01
#  8.38023259e-02 7.26642206e-02 4.44552982e-02 3.90835518e-02
#  2.58601040e-02 2.47160630e-02 1.21145241e-02 9.66975239e-03
#  4.75704059e-03 3.33391429e-03 2.73585204e-03 1.64831569e-03
#  9.64987017e-04 5.46316414e-04 2.83703169e-04 1.98417658e-04
#  1.72762234e-04 1.33701741e-04 8.04382036e-05 5.53419585e-05
#  4.52633148e-05 3.53970583e-05 1.83991984e-05 1.01721810e-05
#  7.49419819e-06 3.26353882e-06 3.05246506e-06 1.00671496e-06
#  4.74769807e-07 5.11143014e-08 6.63564782e-09 8.81527203e-10
#  2.55254351e-31 2.55254351e-31]

# %%
# Calculate the cumulative explained variance
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

# Plot the cumulative explained variance
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o', linestyle='--')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance vs. Number of Components')
plt.grid(True)
plt.show()

# %%
# Reducir la dimensionalidad utilizando PCA para seleccionar características no correlacionadas
# Separar las características numéricas
features = data_scaled_df.drop(columns=['type_building'])
pca = PCA(n_components=4)  # Seleccionamos un número razonable de componentes principales
principal_components = pca.fit_transform(features)

# Convertir a DataFrame para mantener la consistencia
principal_df =pd.DataFrame(principal_components, columns=[f'PC{i+1}' for i in range(principal_components.shape[1])])

# # Añadir de nuevo la columna 'type_building'
# principal_df['type_building'] = data_reduced['type_building']

# %%
principal_df.head()
# Out:
#         PC1       PC2       PC3       PC4
# 0 -3.018649  0.299312 -0.928156 -0.519008
# 1 -3.012386  0.298144 -0.928003 -0.515751
# 2 -3.007117  0.297441 -0.927956 -0.513943
# 3 -3.029844  0.302268 -0.928045 -0.526625
# 4 -3.029593  0.303796 -0.928212 -0.527324

# %%
# Paso 1: Examinar las Componentes Principales (PCA)
pca_loadings = pd.DataFrame(pca.components_.T, index=features.columns, columns=[f'PC{i+1}' for i in range(pca.n_components_)])
pca_loadings
# Out:
#                                                          PC1       PC2  \
# Electricity:Facility [kW](Hourly)_mean              0.191873  0.044660
# Electricity:Facility [kW](Hourly)_std_dev           0.167968 -0.220140
# Electricity:Facility [kW](Hourly)_max_value         0.185553 -0.119521
# Electricity:Facility [kW](Hourly)_min_value         0.182704  0.137480
# Electricity:Facility [kW](Hourly)_25_percentile     0.173650  0.194748
# Electricity:Facility [kW](Hourly)_50_percentile     0.186203  0.091982
# Electricity:Facility [kW](Hourly)_75_percentile     0.192013 -0.002285
# Fans:Electricity [kW](Hourly)_mean                  0.164575  0.208649
# Fans:Electricity [kW](Hourly)_std_dev               0.110751 -0.216924
# Fans:Electricity [kW](Hourly)_max_value             0.185495 -0.038689
# Fans:Electricity [kW](Hourly)_min_value             0.138715  0.311551
# Fans:Electricity [kW](Hourly)_25_percentile         0.134792  0.318554
# Fans:Electricity [kW](Hourly)_50_percentile         0.159101  0.228318
# Fans:Electricity [kW](Hourly)_75_percentile         0.166320  0.098484
# Cooling:Electricity [kW](Hourly)_mean               0.180259  0.143966
# Cooling:Electricity [kW](Hourly)_std_dev            0.157802 -0.196629
# Cooling:Electricity [kW](Hourly)_max_value          0.166310 -0.123740
# Cooling:Electricity [kW](Hourly)_min_value          0.064204  0.162430
# Cooling:Electricity [kW](Hourly)_25_percentile      0.138358  0.300844
# Cooling:Electricity [kW](Hourly)_50_percentile      0.149278  0.282972
# Cooling:Electricity [kW](Hourly)_75_percentile      0.186061  0.057100
# Heating:Electricity [kW](Hourly)_mean              -0.030686  0.033648
# Heating:Electricity [kW](Hourly)_std_dev           -0.031841  0.032193
# Heating:Electricity [kW](Hourly)_max_value         -0.032066  0.033089
# Heating:Electricity [kW](Hourly)_min_value          0.000000  0.000000
# Heating:Electricity [kW](Hourly)_25_percentile      0.000000  0.000000
# Heating:Electricity [kW](Hourly)_50_percentile     -0.008186  0.050618
# Heating:Electricity [kW](Hourly)_75_percentile     -0.027523  0.038429
# InteriorLights:Electricity [kW](Hourly)_mean        0.182026 -0.151009
# InteriorLights:Electricity [kW](Hourly)_std_dev     0.164336 -0.226964
# InteriorLights:Electricity [kW](Hourly)_max_value   0.171245 -0.199534
# InteriorLights:Electricity [kW](Hourly)_min_value   0.162742 -0.092032
# InteriorLights:Electricity [kW](Hourly)_25_perc...  0.164153  0.003183
# InteriorLights:Electricity [kW](Hourly)_50_perc...  0.186397  0.089862
# InteriorLights:Electricity [kW](Hourly)_75_perc...  0.169743 -0.208117
# InteriorEquipment:Electricity [kW](Hourly)_mean     0.181165 -0.083025
# InteriorEquipment:Electricity [kW](Hourly)_std_dev  0.175947 -0.112939
# InteriorEquipment:Electricity [kW](Hourly)_max_...  0.178044 -0.118122
# InteriorEquipment:Electricity [kW](Hourly)_min_...  0.180319 -0.096277
# InteriorEquipment:Electricity [kW](Hourly)_25_p...  0.179017 -0.111760
# InteriorEquipment:Electricity [kW](Hourly)_50_p...  0.186239 -0.017032
# InteriorEquipment:Electricity [kW](Hourly)_75_p...  0.176393 -0.075056
#
#                                                          PC3       PC4
# Electricity:Facility [kW](Hourly)_mean              0.013220 -0.036756
# Electricity:Facility [kW](Hourly)_std_dev           0.028202  0.049319
# Electricity:Facility [kW](Hourly)_max_value         0.031959  0.051268
# Electricity:Facility [kW](Hourly)_min_value        -0.004411 -0.055879
# Electricity:Facility [kW](Hourly)_25_percentile    -0.004645 -0.042415
# Electricity:Facility [kW](Hourly)_50_percentile     0.016826 -0.104222
# Electricity:Facility [kW](Hourly)_75_percentile     0.024837 -0.063861
# Fans:Electricity [kW](Hourly)_mean                 -0.016509  0.154373
# Fans:Electricity [kW](Hourly)_std_dev              -0.058307  0.442152
# Fans:Electricity [kW](Hourly)_max_value             0.005629 -0.032140
# Fans:Electricity [kW](Hourly)_min_value            -0.015651  0.009140
# Fans:Electricity [kW](Hourly)_25_percentile         0.003922  0.008372
# Fans:Electricity [kW](Hourly)_50_percentile         0.009465 -0.045029
# Fans:Electricity [kW](Hourly)_75_percentile        -0.036119  0.310568
# Cooling:Electricity [kW](Hourly)_mean              -0.015372  0.080567
# Cooling:Electricity [kW](Hourly)_std_dev           -0.009674  0.261851
# Cooling:Electricity [kW](Hourly)_max_value         -0.001259  0.307403
# Cooling:Electricity [kW](Hourly)_min_value         -0.013270  0.002079
# Cooling:Electricity [kW](Hourly)_25_percentile     -0.022168  0.008047
# Cooling:Electricity [kW](Hourly)_50_percentile     -0.017121 -0.023506
# Cooling:Electricity [kW](Hourly)_75_percentile     -0.001016  0.011461
# Heating:Electricity [kW](Hourly)_mean               0.475932  0.094145
# Heating:Electricity [kW](Hourly)_std_dev            0.470052  0.091467
# Heating:Electricity [kW](Hourly)_max_value          0.467016  0.089401
# Heating:Electricity [kW](Hourly)_min_value          0.000000 -0.000000
# Heating:Electricity [kW](Hourly)_25_percentile      0.000000 -0.000000
# Heating:Electricity [kW](Hourly)_50_percentile      0.219549  0.042673
# Heating:Electricity [kW](Hourly)_75_percentile      0.474613  0.096220
# InteriorLights:Electricity [kW](Hourly)_mean        0.002509 -0.015810
# InteriorLights:Electricity [kW](Hourly)_std_dev     0.026585 -0.098199
# InteriorLights:Electricity [kW](Hourly)_max_value   0.016051 -0.078579
# InteriorLights:Electricity [kW](Hourly)_min_value  -0.066790  0.319282
# InteriorLights:Electricity [kW](Hourly)_25_perc... -0.080756  0.266562
# InteriorLights:Electricity [kW](Hourly)_50_perc... -0.041067  0.068052
# InteriorLights:Electricity [kW](Hourly)_75_perc...  0.024393 -0.076649
# InteriorEquipment:Electricity [kW](Hourly)_mean     0.066615 -0.193106
# InteriorEquipment:Electricity [kW](Hourly)_std_dev  0.106714 -0.154206
# InteriorEquipment:Electricity [kW](Hourly)_max_...  0.085070 -0.158830
# InteriorEquipment:Electricity [kW](Hourly)_min_...  0.047292 -0.198587
# InteriorEquipment:Electricity [kW](Hourly)_25_p...  0.037332 -0.188921
# InteriorEquipment:Electricity [kW](Hourly)_50_p...  0.041502 -0.181607
# InteriorEquipment:Electricity [kW](Hourly)_75_p...  0.093507 -0.232696

# %% [markdown]
# Las cargas de las componentes principales (PCA) indican qué variables originales tienen mayor influencia en cada componente. Aquí están algunas observaciones clave:

# %% [markdown]
# ## CLUSTERING

# %% [markdown]
# ### KMEANS

# %%
# Método del Codo para K-means
inertia = []
K_range = range(1, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(principal_df.iloc[:, :4])
    inertia.append(kmeans.inertia_)

# Gráfico del Método del Codo
plt.figure(figsize=(10, 6))
plt.plot(K_range, inertia, 'bx-')
plt.xlabel('Número de Clusters K')
plt.ylabel('Inercia')
plt.title('Método del Codo para determinar el número óptimo de clusters')
plt.show()

# %%
# Calcular las diferencias entre inercias
inertia_differences = [j - i for i, j in zip(inertia[:-1], inertia[1:])]
# Imprimir las diferencias entre inercias
for i, diff in enumerate(inertia_differences, start=2):
    print(f"Diferencia de inercia entre {i-1} y {i} clusters: {diff}")
# Out:
# Diferencia de inercia entre 1 y 2 clusters: -1812.266054887887
# Diferencia de inercia entre 2 y 3 clusters: -484.59247485640674
# Diferencia de inercia entre 3 y 4 clusters: -223.71316754415784
# Diferencia de inercia entre 4 y 5 clusters: -295.2711659393142
# Diferencia de inercia entre 5 y 6 clusters: -92.56574258475176
# Diferencia de inercia entre 6 y 7 clusters: -30.753710026582695
# Diferencia de inercia entre 7 y 8 clusters: -29.828269030454212
# Diferencia de inercia entre 8 y 9 clusters: -4.100437819637023
# Diferencia de inercia entre 9 y 10 clusters: -7.052474951883845

# %% [markdown]
# basandonos en la grafica de los cambios de inercia  utilizamos el metodo del codo para determinar el numero optimo de clusters a agrupar estan entre 2 a 3

# %%
# Aplicar K-means con un número de clusters razonable, por ejemplo, 3
kmeans = KMeans(n_clusters=3, random_state=42)
clusters_kmeans = kmeans.fit_predict(principal_df.iloc[:, :4])

# Agregar los clusters al DataFrame para análisis posterior
principal_df['Cluster_KMeans'] = clusters_kmeans
data_scaled_df['Cluster_KMeans'] = clusters_kmeans
# Mostrar los primeros registros con los clusters asignados
principal_df.head()
# Out:
#         PC1       PC2       PC3       PC4  Cluster_KMeans
# 0 -3.018649  0.299312 -0.928156 -0.519008               0
# 1 -3.012386  0.298144 -0.928003 -0.515751               0
# 2 -3.007117  0.297441 -0.927956 -0.513943               0
# 3 -3.029844  0.302268 -0.928045 -0.526625               0
# 4 -3.029593  0.303796 -0.928212 -0.527324               0

# %% [markdown]
# **Silueta**
# El coeficiente de silueta mide cuán similares son los objetos dentro de un mismo cluster comparados con objetos de otros clusters. Va de -1 a 1, donde valores cercanos a 1 indican buenos clusters, cercanos a 0 indican clusters solapados y valores negativos indican asignaciones incorrectas.

# %%
# Calcular el silhouette score para evaluar la calidad de los clusters
silhouette_kmeans = silhouette_score(principal_df.iloc[:, :4], clusters_kmeans)
silhouette_kmeans
# Out:
# 0.7298520425683923

# %% [markdown]
# **Índice de Davies-Bouldin**
# Mide la compactación de los clusters y la separación entre ellos. Un valor más bajo indica una mejor formación de clusters.

# %%
# Calcular el índice de Davies-Bouldin
davies_bouldin = davies_bouldin_score(principal_df.iloc[:, :4], clusters_kmeans)
davies_bouldin
# Out:
# 0.5731114074066508

# %%
# Visualización de los clusters obtenidos por K-means
plt.figure(figsize=(10, 8))
plt.scatter(principal_df["PC1"], principal_df['PC2'], c=principal_df['Cluster_KMeans'], cmap='viridis', s=50, alpha=0.7)
plt.title('Clusters K-means en Componentes Principales')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.colorbar(label='Cluster K-means')
# Assign the cluster centers: centroids
centroids = kmeans.cluster_centers_

# Assign the columns of centroids: centroids_x, centroids_y
centroids_x = centroids[:,0]
centroids_y = centroids[:,1]

# Make a scatter plot of centroids_x and centroids_y
"""
scatter plot of centroids_x and centroids_y, using 'D' (a diamond) as a marker by specifying the marker parameter. Set the size of the markers to be 50 using s=50.
"""
plt.scatter(centroids_x,centroids_y,marker="D",s=50)
plt.show()

# %%
principal_df.head()
# Out:
#         PC1       PC2       PC3       PC4  Cluster_KMeans
# 0 -3.018649  0.299312 -0.928156 -0.519008               0
# 1 -3.012386  0.298144 -0.928003 -0.515751               0
# 2 -3.007117  0.297441 -0.927956 -0.513943               0
# 3 -3.029844  0.302268 -0.928045 -0.526625               0
# 4 -3.029593  0.303796 -0.928212 -0.527324               0

# %%
# Analizar algunas de las variables originales más influyentes en los componentes principales
influential_vars = pca_loadings.abs().sum(axis=1).sort_values(ascending=False).head(5).index

for var in influential_vars:
    plt.figure(figsize=(14, 10))
    sns.boxplot(data=data_scaled_df, x=principal_df['Cluster_KMeans'], y=var)
    plt.title(f'Distribución de {var} por Cluster')
    plt.show()

# %% [markdown]
# ## DBSCAN

# %%
#Calling our main function
idx, eps = get_eps(principal_df.iloc[:, :4])

#Showing the rotated version used for find the elbow.
plt.show()

#Printing the exact values of our eps, from here we will round it
#and use it for our DBSCAN method.
print(eps)
# Out:
# 0.3693333644585501

# %%
# Aplicar DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters_dbscan = dbscan.fit_predict(principal_df.iloc[:, :4])

# Agregar los clusters al DataFrame para análisis posterior
principal_df['Cluster_DBSCAN'] = clusters_dbscan

# Mostrar los primeros registros con los clusters asignados por DBSCAN
principal_df.head()
# Out:
#         PC1       PC2       PC3       PC4  Cluster_KMeans  Cluster_DBSCAN
# 0 -3.018649  0.299312 -0.928156 -0.519008               0               0
# 1 -3.012386  0.298144 -0.928003 -0.515751               0               0
# 2 -3.007117  0.297441 -0.927956 -0.513943               0               0
# 3 -3.029844  0.302268 -0.928045 -0.526625               0               0
# 4 -3.029593  0.303796 -0.928212 -0.527324               0               0

# %% [markdown]
# **Silueta**
# El coeficiente de silueta mide cuán similares son los objetos dentro de un mismo cluster comparados con objetos de otros clusters. Va de -1 a 1, donde valores cercanos a 1 indican buenos clusters, cercanos a 0 indican clusters solapados y valores negativos indican asignaciones incorrectas.

# %%
# Calcular el silhouette score para evaluar la calidad de los clusters, excluyendo los puntos ruidosos
if len(set(clusters_dbscan)) > 1:
    silhouette_dbscan = silhouette_score(principal_df.iloc[:, :4], clusters_dbscan)
else:
    silhouette_dbscan = -1  # Silhouette score no es aplicable si hay un solo cluster
silhouette_dbscan
# Out:
# 0.4374271455137061

# %% [markdown]
# **Índice de Davies-Bouldin**
# Mide la compactación de los clusters y la separación entre ellos. Un valor más bajo indica una mejor formación de clusters.

# %%
# Calcular el índice de Davies-Bouldin
davies_bouldin_dbscan= davies_bouldin_score(principal_df.iloc[:, :4], clusters_dbscan)
davies_bouldin_dbscan
# Out:
# 1.2791317847893648

# %%
# Visualización de los clusters obtenidos por DBSCAN
plt.figure(figsize=(10, 8))
plt.scatter(principal_df['PC1'], principal_df['PC2'], c=principal_df['Cluster_DBSCAN'], cmap='viridis', s=50, alpha=0.7)
plt.title('Clusters DBSCAN en Componentes Principales')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.colorbar(label='Cluster DBSCAN')
plt.show()

# %%
# Analizar algunas de las variables originales más influyentes en los componentes principales
influential_vars = pca_loadings.abs().sum(axis=1).sort_values(ascending=False).head(5).index

for var in influential_vars:
    plt.figure(figsize=(14, 10))
    sns.boxplot(data=data_scaled_df, x=principal_df['Cluster_DBSCAN'], y=var)
    plt.title(f'Distribución de {var} por Cluster')
    plt.show()

# %% [markdown]
# ## CLUSTERING HERARQUICO

# %%
# Calculate the linkage: mergings
mergings = linkage(principal_df.iloc[:, :4],method='complete')

# Plot the dendrogram
dendrogram(mergings,labels= data_scaled_df['type_building'].tolist(),leaf_rotation=90,leaf_font_size=6)
plt.show()

# %%
# Calcular el linkage matrix
mergings = linkage(principal_df.iloc[:, :4], method='complete')

# Calcular las alturas de los clusters
last = mergings[-10:, 2]
last_rev = last[::-1]
indexes = np.arange(1, len(last) + 1)

# Calcular la aceleración
acceleration = np.diff(last, 2)  # Segunda derivada de las alturas
acceleration_rev = acceleration[::-1]

# Encontrar el número óptimo de clusters
k = acceleration_rev.argmax() + 2  # +2 porque la primera derivada se pierde y Python indexa desde 0

print(f'El número óptimo de clusters es: {k}')
# Out:
# El número óptimo de clusters es: 3

# %%
# Aplicar Clustering Jerárquico
hierarchical = AgglomerativeClustering(n_clusters=3)
clusters_hierarchical = hierarchical.fit_predict(principal_df.iloc[:, :4])

# Agregar los clusters al DataFrame para análisis posterior
principal_df['Cluster_Hierarchical'] = clusters_hierarchical

# Mostrar los primeros registros con los clusters asignados por Clustering Jerárquico
principal_df.head()
# Out:
#         PC1       PC2       PC3       PC4  Cluster_KMeans  Cluster_DBSCAN  \
# 0 -3.018649  0.299312 -0.928156 -0.519008               0               0
# 1 -3.012386  0.298144 -0.928003 -0.515751               0               0
# 2 -3.007117  0.297441 -0.927956 -0.513943               0               0
# 3 -3.029844  0.302268 -0.928045 -0.526625               0               0
# 4 -3.029593  0.303796 -0.928212 -0.527324               0               0
#
#    Cluster_Hierarchical
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %% [markdown]
# **Silueta**
# El coeficiente de silueta mide cuán similares son los objetos dentro de un mismo cluster comparados con objetos de otros clusters. Va de -1 a 1, donde valores cercanos a 1 indican buenos clusters, cercanos a 0 indican clusters solapados y valores negativos indican asignaciones incorrectas.

# %%
# Calcular el silhouette score para evaluar la calidad de los clusters
silhouette_hierarchical = silhouette_score(principal_df.iloc[:, :4], clusters_hierarchical)
silhouette_hierarchical
# Out:
# 0.7298520425683923

# %% [markdown]
# **Índice de Davies-Bouldin**
# Mide la compactación de los clusters y la separación entre ellos. Un valor más bajo indica una mejor formación de clusters.

# %%
# Calcular el índice de Davies-Bouldin
davies_bouldin_hierarchical= davies_bouldin_score(principal_df.iloc[:, :4], clusters_hierarchical)
davies_bouldin_hierarchical
# Out:
# 0.5731114074066508

# %%
# Visualización de los clusters obtenidos por Clustering Jerárquico
plt.figure(figsize=(10, 8))
plt.scatter(principal_df["PC1"], principal_df['PC2'], c=principal_df['Cluster_Hierarchical'], cmap='viridis', s=50, alpha=0.7)
plt.title('Clusters Jerárquico en Componentes Principales')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.colorbar(label='Cluster Jerárquico')
plt.show()

# %%
# Analizar algunas de las variables originales más influyentes en los componentes principales
influential_vars = pca_loadings.abs().sum(axis=1).sort_values(ascending=False).head(5).index

for var in influential_vars:
    plt.figure(figsize=(14, 10))
    sns.boxplot(data=data_scaled_df, x=principal_df['Cluster_Hierarchical'], y=var)
    plt.title(f'Distribución de {var} por Cluster')
    plt.show()
