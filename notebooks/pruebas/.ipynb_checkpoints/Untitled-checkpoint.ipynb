# %%
# Correcting the "All Features" metrics
import pandas as pd
import openpyxl

data_with_all_features = {
    'Cluster': [
        'cluster 0', 'cluster 0', 'cluster 0', 'cluster 0',
        'cluster 1', 'cluster 1', 'cluster 1', 'cluster 1',
        'cluster 2', 'cluster 2', 'cluster 2', 'cluster 2',
        'cluster 3', 'cluster 3', 'cluster 3', 'cluster 3'
    ],
    'Method': [
        'Backward Elimination', 'MRMR', 'Vif', 'All Features',
        'Backward Elimination', 'MRMR', 'Vif', 'All Features',
        'Backward Elimination', 'MRMR', 'Vif', 'All Features',
        'Backward Elimination', 'MRMR', 'Vif', 'All Features'
    ],
    'Linear Regression RMSE': [
        3.591, 3.905, 5.407, 3.613025e-14,
        185.804, 43.132, 43.579, 8.824070e-13,
        39.529, 39.889, 41.363, 4.386669e-13,
        48.500, 6.426, 31.104, 6.954435e-14
    ],
    'Linear Regression R2 Score': [
        0.984, 0.981, 0.964, 1.000,
        0.829, 0.991, 0.991, 1.000,
        0.972, 0.972, 0.970, 1.000,
        0.975, 1.000, 0.990, 1.000
    ],
    'Stepwise Linear Regression RMSE': [
        3.591, 3.906, 5.407, 0.010054,
        185.804, 43.133, 43.579, 0.010071,
        39.530, 39.890, 41.364, 0.010213,
        48.499, 6.428, 31.103, 0.009915
    ],
    'Stepwise Linear Regression R2 Score': [
        0.984, 0.981, 0.964, 1.000,
        0.829, 0.991, 0.991, 1.000,
        0.972, 0.972, 0.970, 1.000,
        0.975, 1.000, 0.990, 1.000
    ],
    'Tree RMSE': [
        1.349, 2.015, 1.902, 0.152014,
        61.129, 44.802, 35.785, 1.573045,
        15.170, 9.868, 32.319, 0.302816,
        17.852, 9.338, 25.139, 0.399261
    ],
    'Tree R2 Score': [
        0.998, 0.995, 0.995, 0.999971,
        0.981, 0.990, 0.994, 0.999988,
        0.996, 0.984, 0.982, 0.999998,
        0.997, 0.999, 0.993, 0.999998
    ],
    'SVM RMSE': [
        3.311, 2.780, 3.815, 1.350244,
        167.836, 70.512, 42.865, 80.360183,
        71.865, 58.782, 52.199, 61.541728,
        66.219, 36.325, 46.483, 59.344006
    ],
    'SVM R2 Score': [
        0.986, 0.990, 0.982, 0.997724,
        0.860, 0.975, 0.991, 0.967932,
        0.909, 0.939, 0.952, 0.933021,
        0.954, 0.986, 0.977, 0.962706
    ],
    'Efficient Linear RMSE': [
        3.591, 3.905, 5.407, 3.613025e-14,
        185.804, 43.132, 43.579, 8.824070e-13,
        39.529, 39.889, 41.363, 4.386669e-13,
        48.500, 6.426, 31.104, 6.954435e-14
    ],
    'Efficient Linear R2 Score': [
        0.984, 0.981, 0.964, 1.000,
        0.829, 0.991, 0.991, 1.000,
        0.972, 0.972, 0.970, 1.000,
        0.975, 1.000, 0.990, 1.000
    ],
    'Ensemble RMSE': [
        1.494, 1.886, 2.232, 0.105115,
        81.984, 36.259, 31.704, 1.268221,
        17.044, 25.612, 28.184, 0.162328,
        21.078, 6.727, 22.234, 0.181580
    ],
    'Ensemble R2 Score': [
        0.997, 0.996, 0.994, 0.999986,
        0.967, 0.993, 0.995, 0.999992,
        0.995, 0.988, 0.986, 1.000,
        0.995, 0.999, 0.995, 1.000
    ],
    'Random Forest RMSE': [
        0.973, 1.493, 1.524, 0.158434,
        59.240, 35.780, 31.161, 2.258041,
        11.081, 23.658, 27.463, 0.339138,
        14.228, 7.316, 21.249, 0.221761
    ],
    'Random Forest R2 Score': [
        0.999, 0.997, 0.997, 0.999969,
        0.983, 0.994, 0.995, 0.999975,
        0.998, 0.990, 0.987, 0.999998,
        0.998, 0.999, 0.995, 0.999999
    ]
}

# Create DataFrame
df_with_all_features = pd.DataFrame(data_with_all_features)

# Save to Excel
file_path_with_all_features = "cluster_metrics_with_all_features.xlsx"
df_with_all_features.to_excel(file_path_with_all_features, index=False)

# %%
# Create the DataFrame with the provided data
data = {
    'Cluster': ['cluster 0', 'cluster 0', 'cluster 0', 'cluster 0',
                'cluster 1', 'cluster 1', 'cluster 1', 'cluster 1',
                'cluster 2', 'cluster 2', 'cluster 2', 'cluster 2',
                'cluster 3', 'cluster 3', 'cluster 3', 'cluster 3'],
    'Method': ['Backward Elimination', 'MRMR', 'Vif', 'All Features',
               'Backward Elimination', 'MRMR', 'Vif', 'All Features',
               'Backward Elimination', 'MRMR', 'Vif', 'All Features',
               'Backward Elimination', 'MRMR', 'Vif', 'All Features'],
    'Linear Regression RMSE': [3.397115, 3.624990, 3.452286, 3.143843e-13,
                               201.346823, 46.261744, 46.108145, 1.331954e-13,
                               45.821831, 31.451196, 46.102851, 3.714735e-13,
                               23.837383, 52.461485, 32.418883, 3.186363e-13],
    'Linear Regression R2 Score': [0.977648, 0.974549, 0.976916, 1.000000,
                                   0.813959, 0.990179, 0.990244, 1.000000,
                                   0.966560, 0.984246, 0.966148, 1.000000,
                                   0.994724, 0.974446, 0.990242, 1.000000],
    'Stepwise Linear Regression RMSE': [3.397512, 3.625302, 3.452394, 0.010178,
                                        201.348034, 46.264419, 46.107940, 0.010086,
                                        45.822303, 31.453091, 46.102868, 0.010175,
                                        23.838192, 52.460737, 32.418615, 0.010010],
    'Stepwise Linear Regression R2 Score': [0.977643, 0.974545, 0.976915, 1.000000,
                                            0.813956, 0.990178, 0.990244, 1.000000,
                                            0.966559, 0.984244, 0.966148, 1.000000,
                                            0.994724, 0.974446, 0.990242, 1.000000],
    'Tree RMSE': [1.106242, 3.410275, 3.368006, 0.056231,
                  122.048348, 44.827797, 35.719070, 0.467121,
                  22.885451, 22.401159, 38.653155, 0.318687,
                  11.284784, 38.923802, 25.546972, 0.533130],
    'Tree R2 Score': [0.997630, 0.977475, 0.978030, 0.999994,
                      0.931643, 0.990778, 0.994145, 0.999999,
                      0.991659, 0.992008, 0.976205, 0.999998,
                      0.998818, 0.985933, 0.993940, 0.999997],
    'SVM RMSE': [2.818242, 3.583374, 3.676964, 1.208405,
                 200.510555, 69.861803, 45.474648, 54.683966,
                 78.522488, 82.781127, 59.387889, 83.623319,
                 44.338164, 71.996887, 52.994710, 74.224798],
    'SVM R2 Score': [0.984617, 0.975130, 0.973814, 0.997172,
                     0.815501, 0.977602, 0.990510, 0.986277,
                     0.901800, 0.890860, 0.943828, 0.888628,
                     0.981747, 0.951871, 0.973924, 0.948846],
    'Efficient Linear RMSE': [3.397115, 3.624990, 3.452286, 3.143843e-13,
                              201.346823, 46.261744, 46.108145, 1.331954e-13,
                              45.821831, 31.451196, 46.102851, 3.714735e-13,
                              23.837383, 52.461485, 32.418883, 3.186363e-13],
    'Efficient Linear R2 Score': [0.977648, 0.974549, 0.976916, 1.000000,
                                  0.813959, 0.990179, 0.990244, 1.000000,
                                  0.966560, 0.984246, 0.966148, 1.000000,
                                  0.994724, 0.974446, 0.990242, 1.000000],
    'Ensemble RMSE': [1.457211, 3.258761, 3.195660, 0.031513,
                      123.418934, 38.820755, 32.380664, 0.268319,
                      22.452935, 18.539699, 33.467969, 0.147436,
                      11.334193, 36.361779, 23.288726, 0.273015],
    'Ensemble R2 Score': [0.995887, 0.979432, 0.980221, 0.999998,
                          0.930099, 0.993084, 0.995188, 1.000000,
                          0.991971, 0.994526, 0.982161, 1.000000,
                          0.998807, 0.987724, 0.994964, 0.999999],
    'Random Forest RMSE': [0.969626, 3.237209, 3.190055, 0.045644,
                           116.847430, 38.242286, 31.258579, 0.429792,
                           17.419508, 15.551540, 32.645047, 0.195861,
                           8.904880, 33.644755, 21.416510, 0.349654],
    'Random Forest R2 Score': [0.998179, 0.979703, 0.980290, 0.999996,
                               0.937345, 0.993289, 0.995516, 0.999999,
                               0.995167, 0.996148, 0.983027, 0.999999,
                               0.999264, 0.989490, 0.995741, 0.999999]
}

df = pd.DataFrame(data)

# Apply formatting for three decimal places except for "All Features"
df.loc[df['Method'] != 'All Features', df.columns[2:]] = df.loc[df['Method'] != 'All Features', df.columns[2:]].applymap(lambda x: f'{float(x):.3f}')

# Convert the DataFrame to Excel file
file_path = "cluster_metrics_formatted.xlsx"
df.to_excel(file_path, index=False)
# Out:
# C:\Users\ASUS TUF\AppData\Local\Temp\ipykernel_14360\661130886.py:72: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.loc[df['Method'] != 'All Features', df.columns[2:]] = df.loc[df['Method'] != 'All Features', df.columns[2:]].applymap(lambda x: f'{float(x):.3f}')
# C:\Users\ASUS TUF\AppData\Local\Temp\ipykernel_14360\661130886.py:72: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['3.397' '3.625' '3.452' '201.347' '46.262' '46.108' '45.822' '31.451'
#  '46.103' '23.837' '52.461' '32.419']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Method'] != 'All Features', df.columns[2:]] = df.loc[df['Method'] != 'All Features', df.columns[2:]].applymap(lambda x: f'{float(x):.3f}')
# ...

# %%
# Crear los datos
data = {
    "Clustering": ["Utilizando PCA", "Utilizando PCA", "Utilizando PCA", "Utilizando todas las características", "Utilizando todas las características", "Utilizando todas las características"],
    "Método": ["K-means", "DBSCAN", "Clustering jerárquico", "K-means", "DBSCAN", "Clustering jerárquico"],
    "Número de clusters": [3, 14, 4, 3, 1, 4],
    "Coeficiente de Silueta": [0.829, 0.594, 0.841, 0.783, None, 0.813],
    "Índice de Davies-Bouldin": [0.300, 0.989, 0.144, 0.493, None, 0.179]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Exportar a un archivo Excel
file_path = "clustering_results.xlsx"
df.to_excel(file_path, index=False)
