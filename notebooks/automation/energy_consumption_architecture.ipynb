# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import re
# Importaciones específicas del proyecto
from energy_consumption_architecture.utils.paths import data_dir, data_raw_dir
from energy_consumption_architecture.clustering_utils import *
from energy_consumption_architecture.dataset import load_all_series
from energy_consumption_architecture.regresion_utils import pipeline_for_clusters

# %% [markdown]
# ## Cargar datos

# %%
# Especifica el directorio donde están los archivos CSV
carpeta=data_dir("raw")
# Obtén la lista de todos los archivos en la carpeta
archivos = os.listdir(carpeta)
archivos[:5]
# Out:
# ['RefBldgFullServiceRestaurantNew2004_v1.3_7.1_4A_USA_MD_BALTIMORE_Belleville-Scott.csv',
#  'RefBldgFullServiceRestaurantNew2004_v1.3_7.1_4A_USA_MD_BALTIMORE_Cahokia.csv',
#  'RefBldgFullServiceRestaurantNew2004_v1.3_7.1_4A_USA_MD_BALTIMORE_Carbondale-Southern.csv',
#  'RefBldgFullServiceRestaurantNew2004_v1.3_7.1_5A_USA_IL_CHICAGO-OHARE_Aurora.Muni.csv',
#  'RefBldgFullServiceRestaurantNew2004_v1.3_7.1_5A_USA_IL_CHICAGO-OHARE_Bloomington.csv']

# %%
# Define the columns to keep
columns_to_keep = [
    'Date/Time',
    'Cooling:Electricity [kW](Hourly)',
    'InteriorEquipment:Electricity [kW](Hourly)'
]

combined_df_filtered = load_all_series(archivos, columns_to_keep)

# %%
combined_df_filtered.head()
# Out:
#             Date/Time  Cooling:Electricity [kW](Hourly)  \
# 0 2004-01-01 01:00:00                          0.000733
# 1 2004-01-01 02:00:00                          0.000000
# 2 2004-01-01 03:00:00                          0.000000
# 3 2004-01-01 04:00:00                          0.000000
# 4 2004-01-01 05:00:00                          0.000000
#
#    InteriorEquipment:Electricity [kW](Hourly)  \
# 0                                      8.1892
# 1                                      7.4902
# 2                                      7.4902
# 3                                      7.4902
# 4                                      7.4902
#
#                          type_building series_id
# 0  RefBldgFullServiceRestaurantNew2004  series_1
# 1  RefBldgFullServiceRestaurantNew2004  series_1
# 2  RefBldgFullServiceRestaurantNew2004  series_1
# 3  RefBldgFullServiceRestaurantNew2004  series_1
# 4  RefBldgFullServiceRestaurantNew2004  series_1

# %% [markdown]
# ## Clustering

# %%
df_stats = calculate_statistics(combined_df_filtered)

# %%
df_stats.head()
# Out:
#   series_id  Cooling:Electricity [kW](Hourly)_mean  \
# 0  series_1                               3.073887
# 1  series_2                               3.446951
# 2  series_3                               3.973240
# 3  series_4                               2.055950
# 4  series_5                               2.114192
#
#    Cooling:Electricity [kW](Hourly)_std_dev  \
# 0                                  6.226848
# 1                                  6.596764
# 2                                  7.146033
# 3                                  4.688730
# 4                                  4.797245
#
#    InteriorEquipment:Electricity [kW](Hourly)_mean  \
# 0                                        18.995908
# 1                                        18.995908
# 2                                        18.995908
# 3                                        18.995908
# 4                                        18.995908
#
#    InteriorEquipment:Electricity [kW](Hourly)_std_dev
# 0                                           7.265027
# 1                                           7.265027
# 2                                           7.265027
# 3                                           7.265027
# 4                                           7.265027

# %%
metrics, best_model_info, data=automated_clustering(df_stats, max_k=10, eps_range=(0.05, 0.2, 0.05), min_samples_range=(3, 12))
# Out:
# C:\Users\ASUS TUF\.conda\envs\energy_consumption_architecture\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS TUF\.conda\envs\energy_consumption_architecture\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS TUF\.conda\envs\energy_consumption_architecture\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS TUF\.conda\envs\energy_consumption_architecture\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS TUF\.conda\envs\energy_consumption_architecture\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS TUF\.conda\envs\energy_consumption_architecture\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS TUF\.conda\envs\energy_consumption_architecture\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS TUF\.conda\envs\energy_consumption_architecture\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS TUF\.conda\envs\energy_consumption_architecture\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ASUS TUF\.conda\envs\energy_consumption_architecture\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
best_model_info
# Out:
# {'Model': 'K-Means',
#  'Silhouette Score': 0.8357957522052232,
#  'Davies-Bouldin Index': 0.21789734657975474,
#  'Num Clusters': 4,
#  'Silhouette Score Norm': 1.0,
#  'Davies-Bouldin Index Norm': 1.0,
#  'Combined Score': 1.0}

# %%
data.head()
# Out:
#   series_id  Cooling:Electricity [kW](Hourly)_mean  \
# 0  series_1                               3.073887
# 1  series_2                               3.446951
# 2  series_3                               3.973240
# 3  series_4                               2.055950
# 4  series_5                               2.114192
#
#    Cooling:Electricity [kW](Hourly)_std_dev  \
# 0                                  6.226848
# 1                                  6.596764
# 2                                  7.146033
# 3                                  4.688730
# 4                                  4.797245
#
#    InteriorEquipment:Electricity [kW](Hourly)_mean  \
# 0                                        18.995908
# 1                                        18.995908
# 2                                        18.995908
# 3                                        18.995908
# 4                                        18.995908
#
#    InteriorEquipment:Electricity [kW](Hourly)_std_dev  Cluster
# 0                                           7.265027         0
# 1                                           7.265027         0
# 2                                           7.265027         0
# 3                                           7.265027         0
# 4                                           7.265027         0

# %% [markdown]
# ## Regresion

# %%
# Define the columns to keep
columns_to_keep = [
    'Date/Time',
    'Electricity:Facility [kW](Hourly)',
    'Fans:Electricity [kW](Hourly)',
    'Cooling:Electricity [kW](Hourly)',
    'Heating:Electricity [kW](Hourly)',
    'InteriorLights:Electricity [kW](Hourly)',
    'InteriorEquipment:Electricity [kW](Hourly)'
]
data_complete = load_all_series(archivos, columns_to_keep)

# %%
data_complete.head()
# Out:
#             Date/Time  Electricity:Facility [kW](Hourly)  \
# 0 2004-01-01 01:00:00                          22.453919
# 1 2004-01-01 02:00:00                          14.637149
# 2 2004-01-01 03:00:00                          14.651183
# 3 2004-01-01 04:00:00                          14.657947
# 4 2004-01-01 05:00:00                          14.806050
#
#    Fans:Electricity [kW](Hourly)  Cooling:Electricity [kW](Hourly)  \
# 0                       3.998243                          0.000733
# 1                       0.000000                          0.000000
# 2                       0.000000                          0.000000
# 3                       0.000000                          0.000000
# 4                       0.000000                          0.000000
#
#    Heating:Electricity [kW](Hourly)  InteriorLights:Electricity [kW](Hourly)  \
# 0                               0.0                                 4.589925
# 1                               0.0                                 1.529975
# 2                               0.0                                 1.529975
# 3                               0.0                                 1.529975
# 4                               0.0                                 1.529975
#
#    InteriorEquipment:Electricity [kW](Hourly)  \
# 0                                      8.1892
# 1                                      7.4902
# 2                                      7.4902
# 3                                      7.4902
# 4                                      7.4902
#
#                          type_building series_id
# 0  RefBldgFullServiceRestaurantNew2004  series_1
# 1  RefBldgFullServiceRestaurantNew2004  series_1
# 2  RefBldgFullServiceRestaurantNew2004  series_1
# 3  RefBldgFullServiceRestaurantNew2004  series_1
# 4  RefBldgFullServiceRestaurantNew2004  series_1

# %%
# Asegúrate de que el DataFrame `df_stats` contenga las etiquetas de cluster y el `series_id`
# Y que el DataFrame `data_complete` tenga el `series_id`

average_time_series_by_cluster = calculate_average_time_series_by_cluster(data_complete, data)

# %%
average_time_series_by_cluster.head()
# Out:
#                      Cluster  Electricity:Facility [kW](Hourly)  \
# Date/Time
# 2004-01-01 01:00:00        0                          47.210969
# 2004-01-01 02:00:00        0                          47.047291
# 2004-01-01 03:00:00        0                          45.619393
# 2004-01-01 04:00:00        0                          45.697195
# 2004-01-01 05:00:00        0                          47.030928
#
#                      Fans:Electricity [kW](Hourly)  \
# Date/Time
# 2004-01-01 01:00:00                       5.789775
# 2004-01-01 02:00:00                       5.946731
# 2004-01-01 03:00:00                       5.862989
# 2004-01-01 04:00:00                       6.186896
# 2004-01-01 05:00:00                       5.832209
#
#                      Cooling:Electricity [kW](Hourly)  \
# Date/Time
# 2004-01-01 01:00:00                          3.010854
# 2004-01-01 02:00:00                          3.048947
# 2004-01-01 03:00:00                          2.883068
# 2004-01-01 04:00:00                          2.968095
# 2004-01-01 05:00:00                          2.942949
#
#                      Heating:Electricity [kW](Hourly)  \
# Date/Time
# 2004-01-01 01:00:00                          4.637630
# 2004-01-01 02:00:00                          4.450657
# 2004-01-01 03:00:00                          5.406697
# 2004-01-01 04:00:00                          4.801340
# 2004-01-01 05:00:00                          5.603789
#
#                      InteriorLights:Electricity [kW](Hourly)  \
# Date/Time
# 2004-01-01 01:00:00                                 6.918895
# 2004-01-01 02:00:00                                 6.588343
# 2004-01-01 03:00:00                                 5.084587
# 2004-01-01 04:00:00                                 5.084587
# 2004-01-01 05:00:00                                 5.182567
#
#                      InteriorEquipment:Electricity [kW](Hourly)
# Date/Time
# 2004-01-01 01:00:00                                   10.669373
# 2004-01-01 02:00:00                                   10.525933
# 2004-01-01 03:00:00                                   10.308935
# 2004-01-01 04:00:00                                   10.297614
# 2004-01-01 05:00:00                                   10.482863

# %%
target = 'Electricity:Facility [kW](Hourly)'

# %%
# Cargar modelos con configuraciones ajustadas
models = {
    "Linear Regression": LinearRegression(fit_intercept=True, n_jobs=-1),
    "Tree": DecisionTreeRegressor(max_depth=5, min_samples_split=5, random_state=42),
    "SVM": SVR(kernel='rbf', C=1.0, epsilon=0.1),
    "Random Forest": RandomForestRegressor(n_estimators=100, max_depth=5, min_samples_split=10, random_state=42),
    "XGBoost": XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, subsample=0.8, colsample_bytree=0.8, random_state=42)
}

# %%
metrics_df, best_models_df = pipeline_for_clusters(average_time_series_by_cluster, target, models,threshold_ratio=2)
# Out:
# Processing Cluster 0
# Best model for Cluster 0:
# Model         XGBRegressor(base_score=None, booster=None, ca...
# Train RMSE                                             1.677753
# Train MAE                                              1.242559
# Train R2                                               0.996641
# Test RMSE                                              2.418129
# Test MAE                                               1.875946
# Test R2                                                0.990515
# Model Name                                              XGBoost
# Name: 4, dtype: object
#
# Processing Cluster 1
# Best model for Cluster 1:
# Model         LinearRegression(n_jobs=-1)
# Train RMSE                      34.509758
# Train MAE                        27.98159
# Train R2                         0.994399
# Test RMSE                       39.835457
# Test MAE                        31.613485
# Test R2                          0.988051
# Model Name              Linear Regression
# Name: 0, dtype: object
#
# Processing Cluster 2
# Best model for Cluster 2:
# Model         XGBRegressor(base_score=None, booster=None, ca...
# Train RMSE                                            13.238075
# Train MAE                                              9.829072
# Train R2                                               0.996658
# Test RMSE                                             24.246907
# Test MAE                                              19.310649
# Test R2                                                0.990215
# Model Name                                              XGBoost
# Name: 4, dtype: object
#
# Processing Cluster 3
# Best model for Cluster 3:
# Model         LinearRegression(n_jobs=-1)
# Train RMSE                       6.566537
# Train MAE                        5.603544
# Train R2                         0.999608
# Test RMSE                        6.617337
# Test MAE                         5.642924
# Test R2                          0.998601
# Model Name              Linear Regression
# Name: 0, dtype: object

# %%
best_models_df
# Out:
#                                                Model  Train RMSE  Train MAE  \
# 4  XGBRegressor(base_score=None, booster=None, ca...    1.677753   1.242559
# 0                        LinearRegression(n_jobs=-1)   34.509758  27.981590
# 4  XGBRegressor(base_score=None, booster=None, ca...   13.238075   9.829072
# 0                        LinearRegression(n_jobs=-1)    6.566537   5.603544
#
#    Train R2  Test RMSE   Test MAE   Test R2         Model Name
# 4  0.996641   2.418129   1.875946  0.990515            XGBoost
# 0  0.994399  39.835457  31.613485  0.988051  Linear Regression
# 4  0.996658  24.246907  19.310649  0.990215            XGBoost
# 0  0.999608   6.617337   5.642924  0.998601  Linear Regression
